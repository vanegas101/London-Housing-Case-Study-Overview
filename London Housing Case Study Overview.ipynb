# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# %%
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col=None)

# %%
properties.head()
# Out:
#   Unnamed: 0 City of London Barking & Dagenham       Barnet       Bexley  \
# 0        NaT      E09000001          E09000002    E09000003    E09000004
# 1 1995-01-01    91448.98487         50460.2266  93284.51832  64958.09036
# 2 1995-02-01    82202.77314        51085.77983  93190.16963  64787.92069
# 3 1995-03-01    79120.70256        51268.96956  92247.52435  64367.49344
# 4 1995-04-01    77101.20804        53133.50526  90762.87492  64277.66881
#
#          Brent      Bromley       Camden      Croydon       Ealing  ...  \
# 0    E09000005    E09000006    E09000007    E09000008    E09000009  ...
# 1  71306.56698  81671.47692  120932.8881  69158.16225  79885.89069  ...
# 2  72022.26197  81657.55944  119508.8622  68951.09542  80897.06551  ...
# 3  72015.76274  81449.31143  120282.2131  68712.44341  81379.86288  ...
# 4  72965.63094  81124.41227   120097.899  68610.04641  82188.90498  ...
#
#     NORTH WEST YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND  \
# ...

# %%
properties = properties.transpose()

# %%
properties.reset_index().head()
# Out:
#                 index          0                    1                    2  \
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001          91448.98487          82202.77314
# 2  Barking & Dagenham  E09000002           50460.2266          51085.77983
# 3              Barnet  E09000003          93284.51832          93190.16963
# 4              Bexley  E09000004          64958.09036          64787.92069
#
#                      3                    4                    5  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1          79120.70256          77101.20804          84409.14932
# 2          51268.96956          53133.50526          53042.24852
# 3          92247.52435          90762.87492          90258.00033
# 4          64367.49344          64277.66881          63997.13588
#
#                      6                    7                    8  ...  \
# ...

# %%
properties.columns
# Out:
# RangeIndex(start=0, stop=349, step=1)

# %%
test2 = properties.copy()

# %%
test2.head()
# Out:
#                           0                    1                    2    \
# Unnamed: 0                NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# City of London      E09000001          91448.98487          82202.77314
# Barking & Dagenham  E09000002           50460.2266          51085.77983
# Barnet              E09000003          93284.51832          93190.16963
# Bexley              E09000004          64958.09036          64787.92069
#
#                                     3                    4    \
# Unnamed: 0          1995-03-01 00:00:00  1995-04-01 00:00:00
# City of London              79120.70256          77101.20804
# Barking & Dagenham          51268.96956          53133.50526
# Barnet                      92247.52435          90762.87492
# Bexley                      64367.49344          64277.66881
#
#                                     5                    6    \
# Unnamed: 0          1995-05-01 00:00:00  1995-06-01 00:00:00
# ...

# %%
test2.reset_index().head()
# Out:
#                 index          0                    1                    2  \
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001          91448.98487          82202.77314
# 2  Barking & Dagenham  E09000002           50460.2266          51085.77983
# 3              Barnet  E09000003          93284.51832          93190.16963
# 4              Bexley  E09000004          64958.09036          64787.92069
#
#                      3                    4                    5  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1          79120.70256          77101.20804          84409.14932
# 2          51268.96956          53133.50526          53042.24852
# 3          92247.52435          90762.87492          90258.00033
# 4          64367.49344          64277.66881          63997.13588
#
#                      6                    7                    8  ...  \
# ...

# %%
test2.columns = test2.iloc[0]

# %%
test2.head()
# Out:
# Unnamed: 0                NaT           1995-01-01           1995-02-01  \
# Unnamed: 0                NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# City of London      E09000001          91448.98487          82202.77314
# Barking & Dagenham  E09000002           50460.2266          51085.77983
# Barnet              E09000003          93284.51832          93190.16963
# Bexley              E09000004          64958.09036          64787.92069
#
# Unnamed: 0                   1995-03-01           1995-04-01  \
# Unnamed: 0          1995-03-01 00:00:00  1995-04-01 00:00:00
# City of London              79120.70256          77101.20804
# Barking & Dagenham          51268.96956          53133.50526
# Barnet                      92247.52435          90762.87492
# Bexley                      64367.49344          64277.66881
#
# Unnamed: 0                   1995-05-01           1995-06-01  \
# Unnamed: 0          1995-05-01 00:00:00  1995-06-01 00:00:00
# ...

# %%
test2 = test2.drop(test2.index[0])

# %%
test2.head()
# Out:
# Unnamed: 0                NaT   1995-01-01   1995-02-01   1995-03-01  \
# City of London      E09000001  91448.98487  82202.77314  79120.70256
# Barking & Dagenham  E09000002   50460.2266  51085.77983  51268.96956
# Barnet              E09000003  93284.51832  93190.16963  92247.52435
# Bexley              E09000004  64958.09036  64787.92069  64367.49344
# Brent               E09000005  71306.56698  72022.26197  72015.76274
#
# Unnamed: 0           1995-04-01   1995-05-01   1995-06-01   1995-07-01  \
# City of London      77101.20804  84409.14932  94900.51244  110128.0423
# Barking & Dagenham  53133.50526  53042.24852  53700.34831  52113.12157
# Barnet              90762.87492  90258.00033  90107.23471  91441.24768
# Bexley              64277.66881  63997.13588  64252.32335  63722.70055
# Brent               72965.63094  73704.04743  74310.48167  74127.03788
#
# Unnamed: 0           1995-08-01   1995-09-01  ... 2023-03-01 2023-04-01  \
# ...

# %%
test2 = test2.drop(columns='NaT')

# %%
test2.head()
# Out:
# Unnamed: 0           1995-01-01   1995-02-01   1995-03-01   1995-04-01  \
# City of London      91448.98487  82202.77314  79120.70256  77101.20804
# Barking & Dagenham   50460.2266  51085.77983  51268.96956  53133.50526
# Barnet              93284.51832  93190.16963  92247.52435  90762.87492
# Bexley              64958.09036  64787.92069  64367.49344  64277.66881
# Brent               71306.56698  72022.26197  72015.76274  72965.63094
#
# Unnamed: 0           1995-05-01   1995-06-01   1995-07-01   1995-08-01  \
# City of London      84409.14932  94900.51244  110128.0423  112329.4376
# Barking & Dagenham  53042.24852  53700.34831  52113.12157  52232.19868
# Barnet              90258.00033  90107.23471  91441.24768  92361.31512
# Bexley              63997.13588  64252.32335  63722.70055  64432.60005
# Brent               73704.04743  74310.48167  74127.03788   73547.0411
#
# Unnamed: 0           1995-09-01   1995-10-01  ... 2023-03-01 2023-04-01  \
# ...

# %%
test2.columns.name = 'Boroughs'

# %%
test2.head()
# Out:
# Boroughs             1995-01-01   1995-02-01   1995-03-01   1995-04-01  \
# City of London      91448.98487  82202.77314  79120.70256  77101.20804
# Barking & Dagenham   50460.2266  51085.77983  51268.96956  53133.50526
# Barnet              93284.51832  93190.16963  92247.52435  90762.87492
# Bexley              64958.09036  64787.92069  64367.49344  64277.66881
# Brent               71306.56698  72022.26197  72015.76274  72965.63094
#
# Boroughs             1995-05-01   1995-06-01   1995-07-01   1995-08-01  \
# City of London      84409.14932  94900.51244  110128.0423  112329.4376
# Barking & Dagenham  53042.24852  53700.34831  52113.12157  52232.19868
# Barnet              90258.00033  90107.23471  91441.24768  92361.31512
# Bexley              63997.13588  64252.32335  63722.70055  64432.60005
# Brent               73704.04743  74310.48167  74127.03788   73547.0411
#
# Boroughs             1995-09-01   1995-10-01  ... 2023-03-01 2023-04-01  \
# ...

# %%
test2 = test2.round(2)

# %%
test2_filtered = test2[~test2.index.str.contains("Unnamed", na=False)]

# %%
test2_filtered.shape
# Out:
# (45, 348)

# %%
test2_filtered = test2

# %%
test2.head()
# Out:
# Boroughs             1995-01-01  1995-02-01  1995-03-01  1995-04-01  \
# City of London      91448.98487    82202.77    79120.70    77101.21
# Barking & Dagenham   50460.2266    51085.78    51268.97    53133.51
# Barnet              93284.51832    93190.17    92247.52    90762.87
# Bexley              64958.09036    64787.92    64367.49    64277.67
# Brent               71306.56698    72022.26    72015.76    72965.63
#
# Boroughs            1995-05-01  1995-06-01  1995-07-01  1995-08-01  \
# City of London        84409.15    94900.51   110128.04   112329.44
# Barking & Dagenham    53042.25    53700.35    52113.12    52232.20
# Barnet                90258.00    90107.23    91441.25    92361.32
# Bexley                63997.14    64252.32    63722.70    64432.60
# Brent                 73704.05    74310.48    74127.04    73547.04
#
# Boroughs            1995-09-01  1995-10-01  ...  2023-03-01  2023-04-01  \
# City of London       104473.11   108038.12  ...    926023.0    900447.0
# ...

# %%
test2 = test2.loc[:'Westminster']

# %%
test2 = test2.iloc[1:]

# %%
test2.shape
# Out:
# (32, 348)

# %%
def create_price_ratio(df, borough):
    price_1998 = df.loc[borough]['1998-01-01']
    price_2018 = df.loc[borough]['2018-01-01']
    ratio = price_1998 / price_2018
    return ratio

boroughs = test2.index.unique()
for borough in boroughs:
    ratio = create_price_ratio(test2, borough)
    print(f"{borough}: {ratio}")
# Out:
# Barking & Dagenham: 0.19742552732165483
# Barnet: 0.21793041113343647
# Bexley: 0.22468408037037355
# Brent: 0.1898143555848878
# Bromley: 0.22908762027054064
# Camden: 0.19661931442376107
# Croydon: 0.2273446207621546
# Ealing: 0.22712940121292788
# Enfield: 0.22908115002012086
# Greenwich: 0.19884282597822117
# Hackney: 0.15137339126427704
# Hammersmith & Fulham: 0.23219031321717915
# Haringey: 0.18418166491802435
# Harrow: 0.2297613108033658
# Havering: 0.22351538290534265
# Hillingdon: 0.23145959630434132
# Hounslow: 0.23187175635311347
# Islington: 0.1881887651573351
# Kensington & Chelsea: 0.1839744923853983
# Kingston upon Thames: 0.2306116776989348
# Lambeth: 0.1871566278022845
# Lewisham: 0.17773409961779904
# Merton: 0.210391944618362
# Newham: 0.18895274353313568
# Redbridge: 0.21720784188478034
# Richmond upon Thames: 0.23822005038204874
# Southwark: 0.16748673682909815
# Sutton: 0.2389441807772123
# Tower Hamlets: 0.2014341131852066
# Waltham Forest: 0.1645172864922379
# ...

# %%
data = {
    'Barking & Dagenham': 0.19742552732165483,
    'Barnet': 0.21793041113343647,
    'Bexley': 0.22468408037037355,
    'Brent': 0.1898143555848878,
    'Bromley': 0.22908762027054064,
    'Camden': 0.19661931442376107,
    'Croydon': 0.2273446207621546,
    'Ealing': 0.22712940121292788,
    'Enfield': 0.22908115002012086,
    'Greenwich': 0.19884282597822117,
    'Hackney': 0.15137339126427704,
    'Hammersmith & Fulham': 0.23219031321717915,
    'Haringey': 0.18418166491802435,
    'Harrow': 0.2297613108033658,
    'Havering': 0.22351538290534265,
    'Hillingdon': 0.23145959630434132,
    'Hounslow': 0.23187175635311347,
    'Islington': 0.1881887651573351,
    'Kensington & Chelsea': 0.1839744923853983,
    'Kingston upon Thames': 0.2306116776989348,
    'Lambeth': 0.1871566278022845,
    'Lewisham': 0.17773409961779904,
    'Merton': 0.210391944618362,
    'Newham': 0.18895274353313568,
    'Redbridge': 0.21720784188478034,
    'Richmond upon Thames': 0.23822005038204874,
    'Southwark': 0.16748673682909815,
    'Sutton': 0.2389441807772123,
    'Tower Hamlets': 0.2014341131852066,
    'Waltham Forest': 0.1645172864922379,
    'Wandsworth': 0.2008117452965015,
    'Westminster': 0.16085095178416486
}

sorted_data = dict(sorted(data.items(), key=lambda item: item[1], reverse=True))

for borough, ratio in sorted_data.items():
    print(f"{borough}: {ratio}")
# Out:
# Sutton: 0.2389441807772123
# Richmond upon Thames: 0.23822005038204874
# Hammersmith & Fulham: 0.23219031321717915
# Hounslow: 0.23187175635311347
# Hillingdon: 0.23145959630434132
# Kingston upon Thames: 0.2306116776989348
# Harrow: 0.2297613108033658
# Bromley: 0.22908762027054064
# Enfield: 0.22908115002012086
# Croydon: 0.2273446207621546
# Ealing: 0.22712940121292788
# Bexley: 0.22468408037037355
# Havering: 0.22351538290534265
# Barnet: 0.21793041113343647
# Redbridge: 0.21720784188478034
# Merton: 0.210391944618362
# Tower Hamlets: 0.2014341131852066
# Wandsworth: 0.2008117452965015
# Greenwich: 0.19884282597822117
# Barking & Dagenham: 0.19742552732165483
# Camden: 0.19661931442376107
# Brent: 0.1898143555848878
# Newham: 0.18895274353313568
# Islington: 0.1881887651573351
# Lambeth: 0.1871566278022845
# Haringey: 0.18418166491802435
# Kensington & Chelsea: 0.1839744923853983
# Lewisham: 0.17773409961779904
# Southwark: 0.16748673682909815
# ...

# %%
#conclusion- putting the boroughs ratios in descending order shows boroughs, such as Sutton and Richmond upon Thames, have experienced the least amount of pricing increases over the 20 year span, versus boroughs such as Westminster and Hackney have experienced the most the most.
